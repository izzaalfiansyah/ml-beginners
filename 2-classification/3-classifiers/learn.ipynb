# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score,precision_score,confusion_matrix,classification_report, precision_recall_curve
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../data/cuisines_cleaned.csv')

label_df = df['cuisine']
feature_df = df.drop(['Unnamed: 0', 'cuisine'], axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(feature_df, label_df, test_size=0.3)

# %%
C = 10
classifiers = {
    'SVC': SVC(kernel='linear', C=C, probability=True, random_state=0),
    'KNN': KNeighborsClassifier(C),
    'RSFT': RandomForestClassifier(n_estimators=100),
    'ADA': AdaBoostClassifier(n_estimators=100),
}

# %%
n_classifiers = len(classifiers)

for i, (name, classifier) in enumerate(classifiers.items()):
    classifier.fit(x_train, np.ravel(y_train))

    y_pred = classifier.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)

    print("Accuracy (train) for %s: %0.1f%% " % (name, accuracy * 100))
    print(classification_report(y_test, y_pred))
# Out:
# Accuracy (train) for SVC: 76.1%
#               precision    recall  f1-score   support
#
#      chinese       0.66      0.65      0.65       248
#       indian       0.87      0.86      0.86       235
#     japanese       0.76      0.73      0.75       230
#       korean       0.82      0.76      0.79       254
#         thai       0.71      0.81      0.76       232
#
#     accuracy                           0.76      1199
#    macro avg       0.76      0.76      0.76      1199
# weighted avg       0.76      0.76      0.76      1199
#
# Accuracy (train) for KNN: 71.1%
#               precision    recall  f1-score   support
#
#      chinese       0.66      0.67      0.67       248
#       indian       0.81      0.78      0.79       235
#     japanese       0.64      0.77      0.70       230
#       korean       0.92      0.57      0.71       254
#         thai       0.62      0.77      0.69       232
#
#     accuracy                           0.71      1199
#    macro avg       0.73      0.71      0.71      1199
# weighted avg       0.74      0.71      0.71      1199
#
# Accuracy (train) for RSFT: 82.2%
#               precision    recall  f1-score   support
#
#      chinese       0.81      0.74      0.77       248
#       indian       0.88      0.89      0.89       235
#     japanese       0.83      0.78      0.80       230
#       korean       0.86      0.82      0.84       254
#         thai       0.75      0.88      0.81       232
#
#     accuracy                           0.82      1199
#    macro avg       0.82      0.82      0.82      1199
# weighted avg       0.82      0.82      0.82      1199
#
# Accuracy (train) for ADA: 67.5%
#               precision    recall  f1-score   support
#
#      chinese       0.69      0.57      0.63       248
#       indian       0.83      0.76      0.79       235
#     japanese       0.47      0.79      0.59       230
#       korean       0.80      0.65      0.72       254
#         thai       0.75      0.62      0.68       232
#
#     accuracy                           0.67      1199
#    macro avg       0.71      0.68      0.68      1199
# weighted avg       0.71      0.67      0.68      1199
