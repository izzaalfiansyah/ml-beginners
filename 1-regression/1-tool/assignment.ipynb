# %%
# %pip install matplotlib numpy scikit-learn --break-system-packages
# Out:
# ...
# )
# ...
# .17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_linnerud
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x, y = load_linnerud(return_X_y=True)
x_labels = ['chins', 'situps', 'jumps']
y_labels = ['weight', 'waist', 'pulse']

print("X:")
print(x.shape)
print(x_labels)

print()

print("Y:")
print(y.shape)
print(y_labels)
# Out:
# X:
# (20, 3)
# ['chins', 'situps', 'jumps']
# Y:
# (20, 3)
# ['weight', 'waist', 'pulse']

# %%
def train(title, x, y, x_label = None, y_label = None):
  x = x.reshape((-1, 1))

  x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.3)

  model = LinearRegression()
  model.fit(x_train, y_train)

  y_pred = model.predict(x_test)
  print(y_pred.shape)

  plt.title(title)
  plt.scatter(x, y, color='black')
  plt.plot(x_test, y_pred, color="blue")
  if x_label is not None:
    plt.xlabel(x_label)
  if y_label is not None:
    plt.ylabel(y_label)
  plt.show()

# %%
print(x[:,0])
print(y[:,0])

for i in range(3):
  train(f"{y_labels[i]} from {x_labels[i]} exercise", x[:, i], y[:, i], x_labels[i], y_labels[i])
# Out:
# [ 5.  2. 12. 12. 13.  4.  8.  6. 15. 17. 17. 13. 14.  1.  6. 12.  4. 11.
#  15.  2.]
# [191. 189. 193. 162. 189. 182. 211. 167. 176. 154. 169. 166. 154. 247.
#  193. 202. 176. 157. 156. 138.]
# (14,)
# (14,)
# (14,)
